# %%
a = "'xn'"
f = f'{a}'
f
# Out:
# "'xn'"

# %%
len(a)
# Out:
# 4

# %%
import pathlib
x = pathlib.Path('main/')
x = x / 'main.py'
print(f'{x}')
# Out:
# main/main.py

# %%
class A:
    a = 1

a = A()
a.a = 2
print(a.a)
b = A()
print(b.a)
print(A.a)
# Out:
# 2
# 1
# 1

# %%
from jobflow import Flow, job
from jobflow.managers.local import  run_locally

@job
def add(x, y):
    return x + y

job1 = add(1,1)
run_locally(job1)
# Out:
# 2026-03-09 12:56:43,602 INFO Started executing jobs locally
# 2026-03-09 12:56:46,010 INFO Starting job - add (58fb1f8d-2b37-494c-b860-98159eb866cc)
# 2026-03-09 12:56:46,013 INFO Finished job - add (58fb1f8d-2b37-494c-b860-98159eb866cc)
# 2026-03-09 12:56:46,014 INFO Finished executing jobs locally
# {'58fb1f8d-2b37-494c-b860-98159eb866cc': {1: Response(output=2, detour=None, addition=None, replace=None, stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/zhangchangwei/workspace/qdyn'))}}

# %%
from pydantic import BaseModel

class basic_input(BaseModel):
    kspacing: float = 0.04
    encut: float = 500
    
class NVTInputT(basic_input):
    scf_thr: float = 1e-6
    temp_begin: float = 300
    temp_end: float = 300

    parameters: str = ''
    
a= NVTInputT()
print(a.kspacing)
# Out:
# 0.04

# %%
from pymatgen.io.vasp import Incar
incar = Incar.from_file('INCAR')
incar.as_dict()
incar.update(**{'xc': 1})

# %%
incar['Y'] = 1
incar.update(incar)
incar.as_dict()
# Out:
# {'SYSTEM': 'TiO2',
#  'ENCUT': 500.0,
#  'PREC': 'Accurate',
#  'LREAL': 'Auto',
#  'ISPIN': 1,
#  'ISTART': 0,
#  'ICHARG': 2,
#  'NCORE': 8,
#  'NSIM': 16,
#  'KPAR': 4,
#  'ISMEAR': 0,
#  'SIGMA': 0.05,
#  'ALGO': 'Normal',
#  'NELMIN': 4,
#  'NELM': 200,
#  'EDIFF': 1e-06,
#  'ISYM': 0,
#  'IBRION': 0,
#  'NSW': 4000,
#  'POTIM': 1.0,
#  'SMASS': -1,
#  'NBLOCK': 20,
#  'TEBEG': 200,
#  'TEEND': 500,
#  'NWRITE': 1,
#  'LWAVE': False,
#  'LCHARG': False,
#  'MAGMOM': [1, 1, 1, 1, 1, 1],
#  'XC': 1,
#  'Y': 1,
#  '@module': 'pymatgen.io.vasp.inputs',
#  '@class': 'Incar'}

# %%
import numpy as np
a = np.zeros((2,2), dtype=np.bool)
len(a.shape)
# Out:
# 2

# %%
a
# Out:
# array([False, False])

# %%
'{}'.format(int(True))
# Out:
# '1'

# %%
def reorder_td_olap(td_olap, perm1, perm2):
    
    td_olap_tmp = td_olap.copy()
    td_olap_tmp[np.ix_(perm1, perm2)] = td_olap
    
    return td_olap_tmp 
from src.tools.libcanac.mod_hungarian import maximize
a = np.array(
    [[0.1, 0.9, 0.2],
    [0.8, 0.1, 0.3],
    [0.2, 0.3, 0.9]]
)
P = maximize(a)
P = np.array(P)
print(P)
a_reordered = reorder_td_olap(a, P[:,0], P[:,1])
print(a_reordered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 def reorder_td_olap(td_olap: Array, perm1: Array, perm2: Array) -> Array:
#       3     td_olap_tmp = td_olap.copy()
#       4     td_olap_tmp[np.ix_(perm1, perm2)] = td_olap
#
# NameError: name 'Array' is not defined
