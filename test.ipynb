# %%
a = "'xn'"
f = f'{a}'
f
# Out:
# "'xn'"

# %%
len(a)
# Out:
# 4

# %%
import pathlib
x = pathlib.Path('main/')
x = x / 'main.py'
print(f'{x}')
# Out:
# main/main.py

# %%
class A:
    a = 1

a = A()
a.a = 2
print(a.a)
b = A()
print(b.a)
print(A.a)
# Out:
# 2
# 1
# 1

# %%
from jobflow import Flow, job
from jobflow.managers.local import  run_locally

@job
def add(x, y):
    return x + y

job1 = add(1,1)
run_locally(job1)
# Out:
# 2026-03-09 12:56:43,602 INFO Started executing jobs locally
# 2026-03-09 12:56:46,010 INFO Starting job - add (58fb1f8d-2b37-494c-b860-98159eb866cc)
# 2026-03-09 12:56:46,013 INFO Finished job - add (58fb1f8d-2b37-494c-b860-98159eb866cc)
# 2026-03-09 12:56:46,014 INFO Finished executing jobs locally
# {'58fb1f8d-2b37-494c-b860-98159eb866cc': {1: Response(output=2, detour=None, addition=None, replace=None, stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/zhangchangwei/workspace/qdyn'))}}
